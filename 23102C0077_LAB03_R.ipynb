# %% [markdown]
# # LAB03:Basics of Calculations
#
# TANISHA SHARMA|23102C0077

# %% [markdown]
# #1)Addition with data vectors

# %%
c(2,3,5,7)+c(-2,-3,-5,8)
# Out:
# [1]  0  0  0 15

# %%
c(2,3,5,7)+c(8,9)
# Out:
# [1] 10 12 13 16

# %%
c(2,3,5,7) + c(8,9,10)
# Out:
# Warning message in c(2, 3, 5, 7) + c(8, 9, 10):
# “longer object length is not a multiple of shorter object length”
# [1] 10 12 15 15

# %% [markdown]
# #2)Subtraction with data vectors

# %%
c(2,3,5,7) - c(-2,-3, -5, 8)
# Out:
# [1]  4  6 10 -1

# %%
 c(12,13,15,17) - c(8,9)
# Out:
# [1] 4 4 7 8

# %%
c(12,13,15,17) - c(8,9,10)
# Out:
# Warning message in c(12, 13, 15, 17) - c(8, 9, 10):
# “longer object length is not a multiple of shorter object length”
# [1] 4 4 5 9

# %% [markdown]
# #3)Multiplication with data vectors

# %%
c(2,3,5,7) * c(-2,-3,-5,8)
# Out:
# [1]  -4  -9 -25  56

# %%
 c(2,3,5,7) * c(8,9)
# Out:
# [1] 16 27 40 63

# %%
 c(2,3,5,7) * c(8,9,10)
# Out:
# Warning message in c(2, 3, 5, 7) * c(8, 9, 10):
# “longer object length is not a multiple of shorter object length”
# [1] 16 27 50 56

# %% [markdown]
# #4)Division with data vectors

# %%
 c(24,20,8,16) / c(3,4,2,8)
# Out:
# [1] 8 5 4 2

# %%
c(24,20,8,16) / c(4,2)
# Out:
# [1]  6 10  2  8

# %%
 c(24,20,8,16) / c(4,2,8)
# Out:
# Warning message in c(24, 20, 8, 16)/c(4, 2, 8):
# “longer object length is not a multiple of shorter object length”
# [1]  6 10  1  4

# %% [markdown]
# 5)Assignment operator
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
x=20
x
# Out:
# [1] 20

# %%
x<-20
x
# Out:
# [1] 20

# %%
x=apple
# Out:
# Error: object 'apple' not found
# Traceback:

# %%
x='apple'
x
# Out:
# [1] "apple"

# %% [markdown]
# #6)Knowing numbers and characters
# ![image.png](data:image/png;base64,...)

# %%
x=20
is.numeric(x)
is.character(x)
# Out:
# [1] TRUE
# [1] FALSE

# %%
y="apple"
is.character(y)
is.numeric(y)
# Out:
# [1] TRUE
# [1] FALSE

# %% [markdown]
# #7)Converting numbers and characters
#
# ![image.png](data:image/png;base64,...)

# %%
x=20
is.numeric(x)

y=as.character(x)
is.numeric(y)

is.character(y)

y
# Out:
# [1] TRUE
# [1] FALSE
# [1] TRUE
# [1] "20"

# %% [markdown]
# #8)Converting numbers and characters

# %%
y="apple"
is.numeric(y)

is.character(y)

z=as.numeric(y)

is.numeric(z)

is.character(z)

z
# Out:
# [1] FALSE
# [1] TRUE
# Warning message:
# “NAs introduced by coercion”
# [1] TRUE
# [1] FALSE
# [1] NA

# %% [markdown]
# #8)Case sensitivity in  R

# %%
X <- 30
X

x<-20
x

x
# Out:
# [1] 30
# [1] 20
# [1] 20

# %% [markdown]
# #9)Combining values in a data vector

# %%
y=1,22,3,4,5
# Out:
# Error in parse(text = input): <text>:1:4: unexpected ','
# 1: y=1,
#        ^
# Traceback:

# %%
y=(1,2,3,4,5)
# Out:
# Error in parse(text = input): <text>:1:5: unexpected ','
# 1: y=(1,
#         ^
# Traceback:

# %%
y=c(1,2,3,4,5)
y
# Out:
# [1] 1 2 3 4 5

# %% [markdown]
# #10) MODE
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
x=6
x
mode(x)

y='apple'
y
mode(y)
# Out:
# [1] 6
# [1] "numeric"
# [1] "apple"
# [1] "character"

# %%
x=6
storage.mode(x)

x=TRUE
storage.mode(x)

x="apple"
storage.mode(x)
# Out:
# [1] "double"
# [1] "logical"
# [1] "character"

# %% [markdown]
# #11)Infinity
#
# ![image.png](data:image/png;base64,...)

# %%
3/0

5+Inf

x=5+Inf
is.finite(x)

is.infinite(x)
# Out:
# [1] Inf
# [1] Inf
# [1] FALSE
# [1] TRUE

# %% [markdown]
# #12)R as a calculator
#
# ![image.png](data:image/png;base64,...)

# %%
2+3

2-3

2*3

3/2

2*3-4+5/6

(2+3)*5+5-10

(((2+3)*5+5)-10)/2

#blank space has no role in calculations

2       +5
# Out:
# [1] 5
# [1] -1
# [1] 6
# [1] 1.5
# [1] 2.833333
# [1] 20
# [1] 10
# [1] 7

# %% [markdown]
# #13)Addition with Scalar

# %%
c(2,3,5,7)+10
# Out:
# [1] 12 13 15 17

# %% [markdown]
# #14)Subtraction with scalar

# %%
c(12,13,15,17)-10
# Out:
# [1] 2 3 5 7

# %% [markdown]
# #15)Multiplication with scalar

# %%
c(2,3,5,7)*10
# Out:
# [1] 20 30 50 70

# %% [markdown]
# #16)Division with scalar

# %%
c(12,13,15,17)/10
# Out:
# [1] 1.2 1.3 1.5 1.7

# %% [markdown]
# #17)Addition with data vectors

# %%
c(2,3,5,7)+c(-22,-3,-5,-8)
# Out:
# [1] -20   0   0  -1

# %% [markdown]
# #18)R as Calci

# %%
2^3

2**3

2^0.5

2^-0.5
# Out:
# [1] 8
# [1] 8
# [1] 1.414214
# [1] 0.7071068

# %% [markdown]
# #19)Power op wth scalar

# %%
c(2,3,5,7)^2
# Out:
# [1]  4  9 25 49

# %% [markdown]
# # 20)Power op with vector

# %%
c(2,3,5,7)^c(2,3)

c(1,2,3,4,5,6)^c(2,3,4)

c(2,3,5,7)^c(2,3,4)
# Out:
# [1]   4  27  25 343
# [1]    1    8   81   16  125 1296
# Warning message in c(2, 3, 5, 7)^c(2, 3, 4):
# “longer object length is not a multiple of shorter object length”
# [1]   4  27 625  49

# %% [markdown]
# #21)Integer Div with Scalar

# %%
2 %/%2

5 %/% 2

7 %/% 3

c(2,3,5,7) %/% 2
# Out:
# [1] 1
# [1] 2
# [1] 2
# [1] 1 1 2 3

# %% [markdown]
# #22)Integer div with data vector

# %%
c(2,3,5,7) %/% c(2,3)

c(2,3,5) %/% c(2,3)
# Out:
# [1] 1 1 2 2
# Warning message in c(2, 3, 5)%/%c(2, 3):
# “longer object length is not a multiple of shorter object length”
# [1] 1 1 2

# %% [markdown]
# 23)Modulo Division (x mod y) with scalars,data vectors

# %%
2%%2

3%%2

c(2,3,5,7) %% 2

 c(2,3,5,7) %% c(2,3)

 c(2,3,5) %% c(2,3)
# Out:
# [1] 0
# [1] 1
# [1] 0 1 1 1
# [1] 0 0 1 1
# Warning message in c(2, 3, 5)%%c(2, 3):
# “longer object length is not a multiple of shorter object length”
# [1] 0 0 1

# %% [markdown]
# 23)R as Calci

# %%
max(1,99)

max(c(1.2,2.9,3.9))

min(99.01,99)

max(c(1.2,2.9,3.9))

 mean(2, 3, 4)

 mean(c(2, 3, 4))
# Out:
# [1] 99
# [1] 3.9
# [1] 99
# [1] 3.9
# [1] 2
# [1] 3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
abs(-4)

 abs(c(-1,-2,-3,4,5))

 sqrt(4)

 sum(c(2,3,5,7))

 prod(c(2,3,5,7))

 round(1.23)

 round(1.83)

 log(10)

 log(exp (1))

 log10(c(10, 100, 1000))
# Out:
# [1] 4
# [1] 1 2 3 4 5
# [1] 2
# [1] 17
# [1] 210
# [1] 1
# [1] 2
# [1] 2.302585
# [1] 1
# [1] 1 2 3

# %% [markdown]
# #24)Assignments

# %%
x1=c(1,2,3,4)
x1

x2=x1^2
x2

c(1,2,3,4) + sum(c(1,2,3,4)) * prod(c(1,2))

 abs( c(1,2,3,4) - sum(c(1,2,3,4))*prod(c(1,2)) )
# Out:
# [1] 1 2 3 4
# [1]  1  4  9 16
# [1] 21 22 23 24
# [1] 19 18 17 16

# %% [markdown]
# #25)Matrix

# %%
x=matrix(nrow=4,ncol=2,
         data=c(1,2,3,4,5,6,7,8))
x

x[3,2]
# Out:
#      [,1] [,2]
# [1,] 1    5
# [2,] 2    6
# [3,] 3    7
# [4,] 4    8
# [1] 7

# %%
#Entering data column wise in a matrix
x = matrix( nrow=4, ncol=2,
data=c(1,2,3,4,5,6,7,8), byrow = FALSE)
x

dim(x)
nrow(x)
ncol(x)
mode(x)
attributes(x)

#Entering data row wise in a matrix
y = matrix( nrow=4, ncol=2,
data=c(1,2,3,4,5,6,7,8), byrow = TRUE)
y
# Out:
#      [,1] [,2]
# [1,] 1    5
# [2,] 2    6
# [3,] 3    7
# [4,] 4    8
# [1] 4 2
# [1] 4
# [1] 2
# [1] "numeric"
# $dim
# [1] 4 2
#      [,1] [,2]
# [1,] 1    2
# [2,] 3    4
# [3,] 5    6
# [4,] 7    8

# %%
help("matrix")

# %%
is.matrix(as.matrix(1:10))
data(warpbreaks)
!is.matrix(warpbreaks)# data.frame, NOT matrix!
warpbreaks[1:10,]
as.matrix(warpbreaks[1:10,]) #using
# Out:
# [1] TRUE
# [1] TRUE
#    breaks wool tension
# 1  26     A    L
# 2  30     A    L
# 3  54     A    L
# 4  25     A    L
# 5  70     A    L
# 6  52     A    L
# 7  51     A    L
# 8  26     A    L
# 9  67     A    L
# 10 18     A    M
#    breaks wool tension
# 1  26     A    L
# 2  30     A    L
# 3  54     A    L
# 4  25     A    L
# 5  70     A    L
# 6  52     A    L
# 7  51     A    L
# 8  26     A    L
# 9  67     A    L
# 10 18     A    M
